# %% [markdown]
# # Guided Project: Analyzing Wikipedia Pages

# %% [markdown]
# List all of the files in the wiki folder.

# %%
import os
os.listdir("wiki")
# Out:
# ['Furubira_District,_Hokkaido.html',
#  'Valentin_Yanin.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'William_Harvey_Lillard.html',
#  'Radial_Road_3.html',
#  'George_Weldrick.html',
#  'Zgornji_Otok.html',
#  'Blue_Heelers_(season_8).html',
#  'Taggen_Nunatak.html',
#  '1951_National_League_tie-breaker_series.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'Vrila.html',
#  'William_Henry_Porter.html',
#  'Clive_Brown_(footballer).html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Blick_nach_Rechts.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Alexios_Aspietes.html',
#  'Mei_Lanfang.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  'Coalville_Town_railway_station.html',
#  'Gennady_Lesun.html',
#  'Bartrum_Glacier.html',
#  'Victor_S._Mamatey.html',
#  'Gottfried_Keller.html',
#  'Table_Point_Formation.html',
#  'Nobuhiko_Ushiba.html',
#  'Master_of_Space_and_Time.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Eressa_aperiens.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Myrtle_(sternwheeler).html',
#  'Abanycha_bicolor.html',
#  'Aubrey_Fair.html',
#  'Urban_chicken.html',
#  'Elgin_National_Watch_Company.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bluesin%27_Around.html',
#  'Pr%C3%A9liminaires.html',
#  'Antae_temple.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Sverre_Solberg.html',
#  'John_Reid_(British_Army_officer).html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Fischli.html',
#  'Aylon_Darwin_Tavella.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'Alexander_Rizzoni.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Jules_Verne_ATV.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'Battle_of_Isonzo_(489).html',
#  'Pictogram.html',
#  'Alan_Oakley.html',
#  'Le_Premier_Sexe.html',
#  'Eugamandus_brunneus.html',
#  'Arthur_Norman.html',
#  'Feel_No_Fret.html',
#  'Claire_Danes.html',
#  'Adish_Aggarwala.html',
#  'Egg_coffee.html',
#  'Diplacus_aurantiacus.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Supermoon.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Olivaceous_flatbill.html',
#  'Javier_Bruses.html',
#  'Mitrella_guerreiroi.html',
#  'Louis_Vivet.html',
#  'Yarkant_County.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Theonellamide_F.html',
#  'PTPRS.html',
#  'Legge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Tom_Buffington.html',
#  'Leuke_Kome.html',
#  'Horace_Pinker.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Kelvin_R._Throop.html',
#  'Yemeni_rial.html',
#  'Miss_Guatemala_2008.html',
#  'Merwin_Hodel.html',
#  'A_Beautiful_Valley.html',
#  'H._T._Hackney_Company.html',
#  'Berzeliustinden.html',
#  'John_Nelson_(merchant).html',
#  'Short_Message_service_center.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Streatfeild_family.html',
#  'Kendal_Williams.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Tam%C3%A1s_Buday.html',
#  'Jeff_Weise.html',
#  'William_Harper_(South_Carolina).html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Shanghai_Shuffle.html',
#  'Danny_Gray.html',
#  'Platinum_fulminate.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Jeecy-Vea.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Mike_Purdy.html',
#  'Hagen_Hauptbahnhof.html',
#  'Patrick_F._Philbin.html',
#  'Ribboned_sweetlips.html',
#  'Endre_Church.html',
#  'Nabil_Baha.html',
#  'Mudramothiram.html',
#  'Schlettau.html',
#  'Ameenapuram.html',
#  'Nathaniel_Merriman.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Mara_Keisling.html',
#  'Ragnar_Gustavsson.html',
#  'William_de_Pembroke.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Mark_Maunder.html',
#  'Wheatland_High_School_(California).html',
#  'Markus_Blutsch.html',
#  'Kristiene_Gong.html',
#  'Punjab_War.html',
#  'Syncretocarpus.html',
#  'Gordon_Bau.html',
#  'Bibliography_of_Niue.html',
#  'Marv_Felderman.html',
#  'Code_page_1023.html',
#  'Discretionary_trust.html',
#  'Cryptographic_primitive.html',
#  'Alex_Kurtzman.html',
#  'William_Samuel_Viner.html',
#  'Nyck_de_Vries.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Scott_McPherson.html',
#  'Kirsten_Klein.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'David_Sands_(psychologist).html',
#  'Beyond_Magnetic.html',
#  'Church_of_the_SubGenius.html',
#  'Vaccinium_padifolium.html',
#  'ZNF644.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Filip_Pyrochta.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Gorgopis_subrimosa.html',
#  'Harry_Lynde_Bradley.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Morgana_King.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Evene.html',
#  'Therese_Maron.html',
#  'Plasnewydd.html',
#  'Belvedere,_London.html',
#  '1958_Wightman_Cup.html',
#  'Bias.html',
#  'Terry_Cox.html',
#  'Heo_Mok.html',
#  'Maple_Jam_Music_Group.html',
#  'Heiko_M%C3%A4rz.html',
#  'Imperial_Venus_(film).html',
#  'Charles_Stuart_(rugby_union).html',
#  'Yarumal.html',
#  'Olive_Dennis.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Bill_Widenhouse.html',
#  'Benny_Lee.html',
#  '1898_Colgate_football_team.html',
#  'Caprinia_versicolor.html',
#  'P%C5%82az%C3%B3wka.html',
#  'MoneyHunt.html',
#  'Neville_Hewitt_(American_football).html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'Dialogue_for_Hungary.html',
#  'Wu_Jin.html',
#  'Kul_Gul.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Two_House_theology.html',
#  'Tramery.html',
#  'Revolutionary_Vol._1.html',
#  'Gaston_Lane.html',
#  'MobiasBanca.html',
#  'Lectionary_69.html',
#  'Arvind_Gokhale.html',
#  'Thomas_Croci.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Medicago_murex.html',
#  'Red-eyed_dove.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Josef_Mik.html',
#  'AVM_GmbH.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Mariana_Mazzucato.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Redwater,_Mississippi.html',
#  'Wangerooge-class_tug.html',
#  'Achaea_faber.html',
#  'Ramana,_Pakistan.html',
#  'Charles_Page_(cricketer).html',
#  'Sweeper.html',
#  'Canbelego_County.html',
#  'Wilson_Global_Explorer.html',
#  'Craig_Chester.html',
#  'Derek_Acorah.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Mountune_Racing.html',
#  'AB_v_CD.html',
#  'Jack_Goes_Home.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Morning_Glory_(2010_film).html',
#  'Flashmob_(album).html',
#  'I_Marine_Expeditionary_Force.html',
#  'KDDQ.html',
#  'Tim_Spencer_(singer).html',
#  'Suri,_Kerman.html',
#  'Seeking_Gaddafi.html',
#  'Jotedar.html',
#  'Kyokutou_I_Love_You.html',
#  'The_Portal_(community_center).html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'S%C3%BCderelbe.html',
#  'Mick_Crotty.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Johnny_Morris_(American_football).html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'Van_Buren,_Ohio.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'The_Wedding_(Sparks_novel).html',
#  'West_Valley,_Washington.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Fureai_kippu.html',
#  'Margo_Reuten.html',
#  'Saladino%27s_Inc.html',
#  'The_Master_Plan_(album).html',
#  'Mark_Baker_(basketball).html',
#  'Zehut.html',
#  'Sol_Eclipse.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  '2004_Tuvalu_A-Division.html',
#  'Jonathan_A._Goldstein.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  '83_(number).html',
#  'SBOA_School_%26_Junior_College.html',
#  'Devil_on_Horseback.html',
#  'Siuniu.html',
#  'Devarampally.html',
#  'SolydXK.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Sierra_Leone_Studies.html',
#  'Harry_Hill_Bandholtz.html',
#  'Bijou,_California.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Pergamus.html',
#  'Biorock.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Antigonadotropin.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Henrique_da_Silveira.html',
#  'Jane_Wrightson.html',
#  'Gregory_Fortuin.html',
#  'Prisons_in_Bolivia.html',
#  'Ga%C5%A1parci.html',
#  'Paul_Maddrell.html',
#  'Vivian_Prokop.html',
#  'Oued_Tl%C3%A9lat.html',
#  'Paser_Crossword_Stela.html',
#  'Shpolskii_matrix.html',
#  'Bruce_Conte.html',
#  'Old_Mill_Creek,_Illinois.html',
#  'SC_Goldau.html',
#  'Robert_Frederick_Blum.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'Sagrai.html',
#  'Falman-County_Acres,_Texas.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'La_Franja.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Unionidae.html',
#  'Corporation_(university).html',
#  '1910_in_literature.html',
#  'Robert_Boehringer.html',
#  'Social_impact_of_YouTube.html',
#  'FC_Khikhani_Khulo.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'The_Lavender_Cowboy.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Tomislav_Erceg.html',
#  'USS_Parris_Island_(AG-72).html',
#  'Meir_Zlotowitz.html',
#  'Awali.html',
#  'Gacharageini.html',
#  'Fortuna_Glacier.html',
#  'Dragnet_(franchise).html',
#  'Winters-Wimberley_House.html',
#  'Ban_On.html',
#  '1915_Montana_football_team.html',
#  'Vijay_Govindarajan.html',
#  'Aiva.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Uralochka_Zlatoust.html',
#  'Sybra_preapicemaculata.html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Josh_West.html',
#  'Second_Valley,_South_Australia.html',
#  'Doug_Sahm_and_Band.html',
#  'Hope_7_(album).html',
#  'Mohamed_El-Sayed.html',
#  'Qalat_Kat.html',
#  'Woodward_Dream_Cruise.html',
#  'USS_Goldcrest.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Aniavan.html',
#  'Instrumental.html',
#  'Christopher_Speer.html',
#  'Maniitsoq_structure.html',
#  'Minardi_M185.html',
#  'Millennium_Art_Academy.html',
#  'Australian_Musician_(magazine).html',
#  'Charlton_baronets.html',
#  'Cheddar_Ales.html',
#  'Dewoitine_D.21.html',
#  'List_of_Bellator_MMA_events.html',
#  'Tubular_Bells_II.html',
#  'Touch_FM_(Coventry).html',
#  'Kadamaha.html',
#  'James_L._Hull.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Pontefract_by-election,_1941.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'Kellie_Jones.html',
#  'Dominique_Voynet.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Garden-based_learning.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Sudanese_pound.html',
#  'Exploratorium_(film).html',
#  'Foulonia.html',
#  'Reb_Russell.html',
#  'Miltochrista_fuscozonata.html',
#  'Luvvie_Darling.html',
#  'Amborella.html',
#  'List_of_Bratz_episodes.html',
#  'Udi,_Enugu.html',
#  'Canyamars.html',
#  'Kenny_Cordray.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Baddiewinkle.html',
#  'Chemin_d%27Aylmer.html',
#  'SSR-180,711.html',
#  'David_Solomona.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'I_Am_Cold.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Rubber_Biscuit.html',
#  'Heald_Green.html',
#  'Charles_Smith_Wilcox.html',
#  'Swathi_Chinukulu.html',
#  'Noise_(song).html',
#  'Maukala.html',
#  'Hilyard_Robinson.html',
#  'Shellie_Morris.html',
#  'Bob_Bass.html',
#  'Diphilus_(physician).html',
#  'Arun_K._Pati.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Sky_Regional_Airlines.html',
#  'Wilhelm_August_Graah.html',
#  'Avenira.html',
#  'Slade_School_of_Fine_Art.html',
#  'Zane_Radcliffe.html',
#  'Devitt_Insurance.html',
#  'Lincoln_Clarkes.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'Bahmanabad-e_Olya.html',
#  'Tarsila_do_Amaral.html',
#  'Ioana_Badea.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'Troso_da_Monza.html',
#  'Walter_of_Durham.html',
#  'James_Wilkes_Maurice.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Ferdinand_Mainzer.html',
#  'Keeled_sideband.html',
#  'Palio_zosterae.html',
#  'Lydia_Villa-Komaroff.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Nickel(II)_hydroxide.html',
#  'Usher_Gahagan.html',
#  'John_V._G._Posey_House.html',
#  'Kfarhata.html',
#  'James_Alexander_Ulio.html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'When_You_Loved_Me.html',
#  'Flat_roof.html',
#  'Jack_Wong.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  'Manhattan_Murder_Mystery.html',
#  'DiGiorgio_Corporation.html',
#  'Eugenio_Morelli.html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  'James_Magee.html',
#  'Bill_Price_(baseball).html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Avengers_Academy.html',
#  'Scrobipalpa_halophila.html',
#  'Swan_neck_deformity.html',
#  'Chhatrasal.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Macroglossum_pseudoluteata.html',
#  'Antibiotic_use_in_livestock.html',
#  'Omaha_Racers.html',
#  'Syngenor.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'List_of_largest_chemical_producers.html',
#  'X-Cops_(band).html',
#  'Hannover_Indians.html',
#  'Carlos_Martins_(musician).html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Asparuh_Peak.html',
#  'Robert_K._Zukowski.html',
#  'Gorfion.html',
#  'Marson.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Jens_Pauli_Skaalum.html',
#  'Chestnut_pie.html',
#  'Vitaly_Bianki.html',
#  'Coronium_(gastropod).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Acacia_dermatophylla.html',
#  'Lis_L%C3%B8wert.html',
#  'Typhoon_Hester_(1952).html',
#  'Ugo_Okoye.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Kokan_Colony.html',
#  'Oleg_Novitskiy.html',
#  'Llwyn-Cus.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Erigeron_canaani.html',
#  'Eternamente_Romanticos.html',
#  'Lecithocera_sextacta.html',
#  'Arthur_Lelyveld.html',
#  'Bonny_River.html',
#  'Charles_Sears.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Tonga_national_basketball_team.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Kusaka_Station.html',
#  'Plze%C5%88_Zoo.html',
#  'WLSR.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Wolfgang_Lutz.html',
#  'Curridge.html',
#  'Kendalia,_Texas.html',
#  'Celebrity_doll.html',
#  'Venezuelan_referendum,_1957.html',
#  'Australian_hardcore.html',
#  'Lake_County_Examiner.html',
#  'HMS_Robust.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'Hermann_Nuding.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Kolound.html',
#  'Ordinary,_Virginia.html',
#  'Kanakomyrtus.html',
#  'Bulbophyllum_biflorum.html',
#  'Copamyntis_infusella.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Charged_Records.html',
#  'Cosmopterix_similis.html',
#  'Jyoti_Raju.html',
#  'Apocephalus_borealis.html',
#  'Bernard-Augustin_Conroy.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Parkgate_railway_station.html',
#  'C11orf30.html',
#  'Mr_Freedom_(fashion).html',
#  'Stade_Municipal_de_Djougou.html',
#  'Suwannee_River_Junior_College.html',
#  'Estelle_v._Smith.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Kentucky_Auditor_election,_2011.html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Tobi_trousers.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Gbiri-Niragu_language.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'List_of_people_from_Bangor,_Maine.html',
#  'One_Night_of_Sin.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'Pustiu_River.html',
#  'Majeepura.html',
#  'Tongyi,_Mingin.html',
#  'Zeiraphera.html',
#  'Benidorm_Bastards.html',
#  'Burmese_shrike.html',
#  'Axel_Revold.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'Daniel_Cerone.html',
#  'Alan_Sheehan.html',
#  'Work_domain_analysis.html',
#  'Pochyta.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Simon%27s_Town_railway_station.html',
#  'Larvicide.html',
#  'Power_transfer_unit.html',
#  'Crab-eating_frog.html',
#  'Percy_William_Bunting.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'KUMT.html',
#  'Vanavara_Airport.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  '55th_parallel_south.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Curtis_Whitley.html',
#  'Post_(structural).html',
#  'Lake_Lagunitas.html',
#  'Failing_Office_Building.html',
#  'Carley_State_Park.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Eyes_Galaxies.html',
#  'Kistenuten.html',
#  'Children_of_the_Grave.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Pushkar.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'KMTZ.html',
#  'Football_Foundation.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Solanum_chilliasense.html',
#  'Ballard_Memorial_High_School.html',
#  'Thanks_Again.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'The_Land_of_the_Dead.html',
#  'Yoshinkan.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'Social_dualism.html',
#  'Golabkhvaran.html',
#  'Liebig_Peak.html',
#  'Garrett_Lucash.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Agnolin.html',
#  'Wren,_Alabama.html',
#  'Roselawn,_Indiana.html',
#  'Brograve_Mill.html',
#  'Ashley,_Wisconsin.html',
#  'Blue_SWAT.html',
#  'HMS_Stratagem_(P234).html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Pedro_Checa.html',
#  'Martha_Herbert.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Adolf_Schulte.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Kiev_Missal.html',
#  'Don_Raye.html',
#  'Precorrin-6A_reductase.html',
#  'Strawberry_foliar_nematode.html',
#  'St._Paul_University_Iloilo.html',
#  'Roger_Brooke.html',
#  'Doumanaba.html',
#  'H._Larue_Renfroe.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Crepidula_atrasolea.html',
#  'Sahanpur.html',
#  'Ksar_Nalut.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'Martinus_Hamconius.html',
#  'Sanford_Wallace.html',
#  'Gratitud.html',
#  'Al-Midan.html',
#  'Iwaki-Ishikawa_Station.html',
#  'Abraham_Stanyan.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Seminemacheilus.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'FC_Bobruisk.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Monarch_Mountain.html',
#  'Johnny_B._Moore.html',
#  'Ayish_Bayou.html',
#  'Newton_Stone.html',
#  'Treaty_of_Ryswick.html',
#  'Kenneth_van_Kempen.html',
#  'Progressive_refinement.html',
#  'Zoom_Systems.html',
#  'Panchamrutham.html',
#  'Hoghiz.html',
#  'Peltigera_membranacea.html',
#  'Bazemore,_Alabama.html',
#  'Ovum_Recordings.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Urodilatin.html',
#  'Stephen_Unwin_(director).html',
#  'Columbia_Airport_(Ohio).html',
#  'Shibanov.html',
#  'DWTE-TV.html',
#  'Bifidocarpus.html',
#  'Priscus_of_Epirus.html',
#  'Bibiana_Beglau.html',
#  'Ordinary_singularity.html',
#  'Castle_of_Cardona.html',
#  'Emmanuel_Muhammad.html',
#  'Bulbonaricus.html',
#  'Kelvin_Mbilinyi.html',
#  'Emily_(1964_song).html',
#  'Ricard_Card%C3%BAs.html',
#  'Greg_Halsey-Brandt.html',
#  'Kim_Yong-hwa.html',
#  'Queensland_Music_Festival.html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Liberty_Central_School_District.html',
#  'Kamakshyanagar.html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'Kattukukke.html',
#  'Tischofer_Cave.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Barren_vegetation.html',
#  'Burbridge_Creek.html',
#  'Bye!_My_Boy!.html',
#  'Phil_Spence.html',
#  'Ronald_McCaffer.html',
#  'Macy_conferences.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Dalian_Road_Station.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Hideki_Kase.html',
#  'Acceptance_(Heroes).html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'RF_microwave_CAE_CAD.html',
#  'Ego_Dominus_Tuus.html',
#  'High_Efficiency_Image_File_Format.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Newfoundland_general_election,_1848.html',
#  'Lungujja.html',
#  'Smeaton,_East_Lothian.html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Ma_Sen.html',
#  'Phenacobius_catostomus.html',
#  'Norderbrarup.html',
#  'Octomeria_lithophila.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Yuga_(film).html',
#  'Clay_Research_Award.html',
#  'Kreslyuvtsi.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Steinkjersannan.html',
#  'Carthage,_Cincinnati.html',
#  'Senapati_district.html',
#  'Frost_Township,_Michigan.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Chhaparband_(Muslim).html',
#  'Guaricana_National_Park.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Appa_(film).html',
#  'Ben_H._Williams.html',
#  'Hypocysta_angustata.html',
#  'Copenhagen_Skatepark.html',
#  'Saratoga_Automobile_Museum.html',
#  'Madhuri_Desai.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Odder.html',
#  'Aldona_Orman.html',
#  'Vancouver_Furious_George.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Dextran_1.html',
#  'HD_90156.html',
#  'WFGI-FM.html',
#  'Oculo-respiratory_syndrome.html',
#  'Zhongxing_Guesthouse.html',
#  '1988_State_of_Origin_series.html',
#  'Hemiargyropsis_frontalis.html',
#  'The_Audacity_to_Podcast.html',
#  'List_of_Polish_consorts.html',
#  'Third_Saturday_in_October.html',
#  'Antipater_of_Thessalonica.html',
#  'Santa_Maria_Imbaro.html',
#  'Brownfield_(software_development).html',
#  'George_Joseph_Trapp.html',
#  'Russell_Road_(Ontario).html',
#  'Maneswar_Brahma.html',
#  'Robin_Brooke.html',
#  '100_Greatest_Romanians.html',
#  'Cristian_Berdeja.html',
#  'King_Parker_House.html',
#  'Al-Nurayn_Mosque.html',
#  'John_Shaw_Rennie.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Meneng_Constituency.html',
#  'List_of_Spaghetti_Western_films.html',
#  'Paul_Kenny_(politician).html',
#  'Luca_Luciano.html',
#  'Cannabis_in_Spain.html',
#  'VSX2.html',
#  'Varsity_College.html',
#  'Fahy,_County_Mayo.html',
#  'Keegan_Pereira_(footballer).html',
#  'Eudonia_notozeucta.html',
#  'Pirama.html',
#  'Shinpei_Matsushita.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Anton_von_Troeltsch.html',
#  'Vang_stone.html',
#  'Heinz_Inniger.html',
#  'Marion_Rockefeller_Weber.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'The_Future_(film).html',
#  'Fusinus_carvalhoriosi.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Weiser_River.html',
#  'Elzear_Torreggiani.html',
#  'Scarlet_wrasse.html',
#  'Svinjare.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Chef_Wan.html',
#  'Viva_Villa!.html',
#  'Jon_Mullich.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'A_Sport_and_a_Pastime.html',
#  'The_Right_Kinda_Lover.html',
#  'Plains,_Kansas.html',
#  'Baadj.html',
#  'George_Ellicott.html',
#  'Cortile_del_Belvedere.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Somarasampettai.html',
#  'David_Jesson.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Nuno_Leal_Maia.html',
#  'Battle_of_Wattignies.html',
#  'Saravan,_Gilan.html',
#  'Colchester_Village_Historic_District.html',
#  'Watsonville_Junction,_California.html',
#  'Hayateumi_Hidehito.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Omar_Onsi.html',
#  'Utiel-Requena.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'ISMACryp.html',
#  'Mirisah.html',
#  'USS_Impeccable_(AM-320).html',
#  'Bengt_Forsberg.html',
#  'Irihirose_Station.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Teiji_Ito.html',
#  'Robert_E._Lee_(FCC).html',
#  'Giardini_Margherita.html',
#  'Upper_Beaches.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Christine_Gardner.html',
#  'Durham_Women%27s_F.C..html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Shoreyjeh-ye_Do.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Luciano_Mercante.html',
#  'Jeff_Boyd.html',
#  'Abbeville_Sluggers.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'Du%C5%A1anovo.html',
#  'Bowie_Race_Track.html',
#  'Gemma_Doyle_(politician).html',
#  'Thornton-le-Beans.html',
#  'Tommy_Hunter_(baseball).html',
#  'S%C3%B8rli.html',
#  'Frithjof_Schmidt.html',
#  'ARA_Garibaldi.html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Schwobsheim.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'L._Fry.html',
#  'Hepatitis_B_virus.html',
#  'Jordan_Steel.html',
#  'Central_Luzon.html',
#  'Jack_Graham_(pastor).html',
#  'Sentences_(composition).html',
#  'Tropical_sprue.html',
#  'Elisa_von_der_Recke.html',
#  'Neurotica.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Moosavi_Peace_Formula.html',
#  'Acrolophus_simulatus.html',
#  'Dennis_Chapman.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'Peter_Collingwood.html',
#  'List_of_molecular_graphics_systems.html',
#  'MOUSE_DHI.html',
#  'Hexachaeta_colombiana.html',
#  'Sot%C4%81panna.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Oligocentris_deciusalis.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Camp_Liberty_killings.html',
#  'Hemet_Public_Library.html',
#  'Lin_Chia-yu.html',
#  'Omiodes_iridias.html',
#  'Shigeo_Kurata.html',
#  'Arthur_L._Aidala.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'The_Purpose_Driven_Church.html',
#  'Brendan_Foster.html',
#  'I%27m_Walking_Behind_You.html',
#  'Glinka_(crater).html',
#  'Larry_Brooks.html',
#  'Socket_423.html',
#  'Double_Wing_Attack.html',
#  'Arkansas_Highway_178.html',
#  'Taylour_Paige.html',
#  'Fraser_Lake_Airport.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Pedro_Machuca.html',
#  'Roll%27s_partridge.html',
#  'Nejat_Alp.html',
#  'Checkerspot_(magazine).html',
#  'Functoid.html',
#  'Manitoba_general_election,_1896.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'Lopez_v._Davis.html',
#  'Coenaculum_secundum.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Sibling_Revelry.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'List_of_birds_of_Malta.html',
#  '2009_English_cricket_season.html',
#  'Banovina_of_Croatia.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Anthony_Marten.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Boogie_Bunnies.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Andrei_Gamalyan.html',
#  'Mykines,_Greece.html',
#  'Dresden-Plauen_railway_station.html',
#  'Kailas_Pal.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'I,_Q_(book_series).html',
#  'Julien_Boisselier.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Joint_Social_Welfare_Institute.html',
#  'The_Summer_King.html',
#  'Burnin%27_Sneakers.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Jazz_in_Turkey.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Luiz_Henrique_Santos.html',
#  'Yasid.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'Ctenodes_zonata.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Carte_Imagine%27R.html',
#  'Holly_Golightly_(comics).html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Matthew_Liptak.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Philaeus.html',
#  'Kate_Harwood.html',
#  'Baltic_Peak.html',
#  'Westchester,_Los_Angeles.html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Pichoy_Airfield.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Desmiphora_bijuba.html',
#  'Webb_Dock_railway_line.html',
#  'Helena_Nyblom.html',
#  'Hall_of_Mental_Cultivation.html',
#  'John_Whewell.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Gulliver_Mickey.html',
#  'Henry_Horace_Williams.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Circus_Avenue.html',
#  'Kettu_Kalyanam.html',
#  'Union_United_Church.html',
#  'Bill_Overstreet.html',
#  'Urs_Burkart.html',
#  'The_K_of_D.html',
#  'Gandigwad.html',
#  'Kentucky_Theater.html',
#  'USS_General_Putnam_(1857).html',
#  'George_Jones_(bishop).html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'The_Hackensaw_Boys.html',
#  'Harry_Sacksioni.html',
#  'David_Beasley.html',
#  'Piracy_on_Falcon_Lake.html',
#  'Mammoth_Unified_School_District.html',
#  'Eggerberg_railway_station.html',
#  'Tillandsia_intermedia.html',
#  'Town_Yetholm.html',
#  'S%27portable_Scoreboards.html',
#  'Sparganothis_saracana.html',
#  'Smilax_laurifolia.html',
#  'Taylor_Williamson.html',
#  'Epropetes_metallica.html',
#  'Melanolagus_bericoides.html',
#  'BBCH-scale_(rice).html',
#  'La_Roca_de_la_Sierra.html',
#  'Russian_Party_in_Estonia.html',
#  'Henry_Louis_Larsen.html',
#  'Torovirinae.html',
#  'Moses_Hardy.html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Els_Dottermans.html',
#  'Epichorista.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Clinton_Engineer_Works.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'The_Showdown_Effect.html',
#  'My_Life_(Billy_Joel_song).html',
#  'Ramo_Stott.html',
#  'Geomancer_(comics).html',
#  'Enrique_Morales.html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Triptolemus_Evrychou.html',
#  'Claudia_Neidig.html',
#  'Keshav_Ginde.html',
#  'Cyclohexane_conformation.html',
#  'Dean_Kukan.html',
#  'List_of_Carboniferous_tetrapods.html',
#  'Sol_Orwell.html',
#  'Lucius_Allen_(politician).html',
#  'Elio_Calderini.html',
#  'Demographics_of_American_Samoa.html',
#  'Middle_Park,_Victoria.html',
#  'Peringiella_denticulata.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Young_Finnish_Party.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Dysgonia_pudica.html',
#  'Klaus_Gerwien.html',
#  'Lee_Henderson_Watkins.html',
#  '%C3%89taule.html',
#  'Sabari.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Ivo_Siromahov.html',
#  'John_Jephson.html',
#  'Land_%26_Water_Australia.html',
#  'Shabbir_Kumar.html',
#  'Sylvia_Moss.html',
#  'West_Park_Bridge.html',
#  'Imperial_amazon.html',
#  '16th_Virginia_Infantry.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Alex_McEachern.html',
#  'Kate_Quarrie.html',
#  'Cyclone_Gamede.html',
#  'William_McDonald_(Australian_politician).html']

# %% [markdown]
# Count up and display the number of files in the wiki folder.

# %%
len(os.listdir("wiki"))
# Out:
# 999

# %% [markdown]
# Display a single file from the wiki folder, and look at the raw HTML. Do you see any patterns?

# %%
with open("wiki/Valentin_Yanin.html") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Valentin Yanin - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Valentin_Yanin","wgTitle":"Valentin Yanin","wgCurRevisionId":736718079,"wgRevisionId":736718079,"wgArticleId":7502081,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles containing Russian-language text","Wikipedia articles with VIAF identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with BNF identifiers","Living people","1929 births","Russian historians","Soviet historians","20th-century historians","Russian archaeologists","Soviet archaeologists","Moscow State University alumni","Moscow State University faculty","Historians of Russia","Full Members of the USSR Academy of Sciences","Full Members of the Russian Academy of Sciences","Demidov Prize laureates","Solzhenitsyn Prize winners","Lenin Prize winners","Recipients of the USSR State Prize","Recipients of the Lomonosov Gold Medal","Recipients of the Order of Lenin","Recipients of the Order of the Red Banner of Labour","Recipients of the Order \"For Merit to the Fatherland\", 4th class"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Valentin_Yanin","wgRelevantArticleId":7502081,"wgRequestId":"WLTGiQpAADkAAHzBy6oAAABK","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q1980377","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.13"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Valentin_Yanin"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Valentin_Yanin&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Valentin_Yanin&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Valentin_Yanin"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Valentin_Yanin rootpage-Valentin_Yanin skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Valentin Yanin</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><p><b>Valentin Lavrentievich Yanin</b> (<a href="/wiki/Russian_language" title="Russian language">Russian</a>: <span lang="ru" xml:lang="ru">Валентин Лаврентьевич Янин</span>, born 6 February 1929 in <a href="/wiki/Kirov,_Kirov_Oblast" title="Kirov, Kirov Oblast">Vyatka</a>) is a leading <a href="/wiki/Russia" title="Russia">Russian</a> historian who has authored 700 books and articles. He has also edited a number of important journals and primary sources, including works on medieval Russian law, <a href="/wiki/Sphragistics" class="mw-redirect" title="Sphragistics">sphragistics</a> and <a href="/wiki/Epigraphy" title="Epigraphy">epigraphy</a>, <a href="/wiki/Archaeology" title="Archaeology">archaeology</a> and history. His expertise is medieval Rus' especially <a href="/wiki/Novgorod_the_Great" class="mw-redirect" title="Novgorod the Great">Novgorod the Great</a>, where he has headed archaeological digs beginning in 1962.</p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Early_life"><span class="tocnumber">1</span> <span class="toctext">Early life</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Research"><span class="tocnumber">2</span> <span class="toctext">Research</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#Honours_and_Positions"><span class="tocnumber">3</span> <span class="toctext">Honours and Positions</span></a></li>
# <li class="toclevel-1 tocsection-4"><a href="#References"><span class="tocnumber">4</span> <span class="toctext">References</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="Early_life">Early life</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=1" title="Edit section: Early life">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>His maternal grandparents were arrested in 1937 and died in a prison camp in 1938. His father was apparently on a list to be executed but escaped this fate and moved with his family to Moscow.<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">[1]</a></sup> Yanin finished his secondary education in 1946, graduating with a Gold Medal; he matriculated at <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State University</a> in 1951.</p>
# <h2><span class="mw-headline" id="Research">Research</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=2" title="Edit section: Research">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In 1954, he defended his <a href="/wiki/Kandidat" class="mw-redirect" title="Kandidat">Kandidat</a> thesis on the <a href="/wiki/Monetary_system" title="Monetary system">monetary systems</a> of pre-Mongol Rus. This was published as <i>The Monetary and Weight System of Medieval Russia</i> ("Денежно-весовые системы русского средневековья") and has become a classic. His doctoral thesis on the <a href="/wiki/Posadnik" title="Posadnik">posadniks</a> of <a href="/wiki/Novgorod" class="mw-redirect" title="Novgorod">Novgorod</a> followed in 1962 and significantly changed our understanding of the constitution of the <a href="/wiki/Novgorod_Republic" title="Novgorod Republic">Novgorod Republic</a>.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">[2]</a></sup> The book demonstrated that the office of posadnik, while subject to election every year, was often held by one man for several consecutive years, sometimes more than a decade, and then passed on to his sons or other members of his clan. It shattered the earlier image of Novgorod as a more democratic republic and showed it to be ruled by a boyar aristocracy (not unlike other medieval republics).</p>
# <p>Yanin's monograph about the seals of Ancient Rus (2 volumes, 1970) summed up half a century of Soviet sphragistics research. After that, Yanin turned his attention to the <a href="/wiki/Birch_bark_document" class="mw-redirect" title="Birch bark document">birch bark documents</a> of <a href="/wiki/Novgorod" class="mw-redirect" title="Novgorod">Novgorod</a>, on which he is considered the greatest living authority (alongside <a href="/wiki/Andrey_Zaliznyak" title="Andrey Zaliznyak">Andrey Zaliznyak</a>).</p>
# <h2><span class="mw-headline" id="Honours_and_Positions">Honours and Positions</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=3" title="Edit section: Honours and Positions">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In 1964, Yanin became professor in the department of archaeology in the Faculty of History at <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State University</a>.</p>
# <p>Since 1978, Yanin has held the chair in archaeology at the Moscow University.</p>
# <p>He is a member of the President's Committee for the Defence of the Material Culture of the Russian Federation and a member of the Consultative Committee of the Ministry of Culture of the Russian Federation.</p>
# <p>In 1962, he was elected a corresponding member of the <a href="/wiki/Soviet_Academy_of_Sciences" class="mw-redirect" title="Soviet Academy of Sciences">Soviet Academy of Sciences</a>; he became a full academician in 1990. In 1999, he became the first historian to be awarded the <a href="/wiki/Lomonosov_Gold_Medal" title="Lomonosov Gold Medal">Lomonosov Gold Medal</a>.</p>
# <p>His other awards include:</p>
# <ul>
# <li><a href="/wiki/Order_of_Merit_for_the_Fatherland" class="mw-redirect" title="Order of Merit for the Fatherland">Order of Merit for the Fatherland 4th class</a></li>
# <li><a href="/wiki/Order_of_Lenin" title="Order of Lenin">Order of Lenin</a></li>
# <li><a href="/wiki/Order_of_the_Red_Banner_of_Labour" title="Order of the Red Banner of Labour">Order of the Red Banner of Labour</a></li>
# <li><a href="/wiki/Order_of_Friendship_of_Peoples" title="Order of Friendship of Peoples">Order of Friendship of Peoples</a></li>
# <li><a href="/wiki/Medal_%22Veteran_of_Labour%22" title="Medal &quot;Veteran of Labour&quot;">Medal "Veteran of Labour"</a></li>
# <li><a href="/wiki/USSR_State_Prize" title="USSR State Prize">USSR State Prize</a> (1970)</li>
# <li><a href="/wiki/Lenin_Prize" title="Lenin Prize">Lenin Prize</a> (1984)</li>
# <li><a href="/wiki/Demidov_Prize" title="Demidov Prize">Demidov Prize</a> (1993)</li>
# <li>State Prize of the Russian Federation (1996)</li>
# <li>Triumph Prize (2002)</li>
# <li><a href="/wiki/Solzhenitsyn_Prize" title="Solzhenitsyn Prize">Solzhenitsyn Prize</a> (2010).</li>
# </ul>
# <p>He is an honorary citizen of Novgorod the Great and an honorary member of the Novgorodian Society of Lovers of Antiquities.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">[3]</a></sup></p>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=4" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><a rel="nofollow" class="external free" href="http://www.whoiswho.ru/russian/Password/journals/11999/yaninr1.htm">http://www.whoiswho.ru/russian/Password/journals/11999/yaninr1.htm</a></span></li>
# <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text">V. L. Yanin, <i>Novgorodskie Posadniki</i> (Moscow: Moscow State University, 1962; reprinted Moscow: Iazyki slavianskoi kul'tury, 2003).</span></li>
# <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text">See Yanin's biography at MGU: <a rel="nofollow" class="external free" href="http://www.hist.msu.ru/Departments/Arch/Staff/Yanin.htm">http://www.hist.msu.ru/Departments/Arch/Staff/Yanin.htm</a></span></li>
# </ol>
# </div>
# <div role="navigation" class="navbox" aria-label="Navbox" style="padding:3px">
# <table class="nowraplinks hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th scope="row" class="navbox-group"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a></th>
# <td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><span style="white-space:nowrap;"><a rel="nofollow" class="external text" href="//www.worldcat.org/identities/containsVIAFID/45138852">WorldCat Identities</a></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Virtual_International_Authority_File" title="Virtual International Authority File">VIAF</a>: <span class="uid"><a rel="nofollow" class="external text" href="https://viaf.org/viaf/45138852">45138852</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Library_of_Congress_Control_Number" title="Library of Congress Control Number">LCCN</a>: <span class="uid"><a rel="nofollow" class="external text" href="http://id.loc.gov/authorities/names/n81115419">n81115419</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Syst%C3%A8me_universitaire_de_documentation" title="Système universitaire de documentation">SUDOC</a>: <span class="uid"><a rel="nofollow" class="external text" href="https://www.idref.fr/061644455">061644455</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Biblioth%C3%A8que_nationale_de_France" title="Bibliothèque nationale de France">BNF</a>: <span class="uid"><a rel="nofollow" class="external text" href="http://catalogue.bnf.fr/ark:/12148/cb120449899">cb120449899</a> <a rel="nofollow" class="external text" href="http://data.bnf.fr/ark:/12148/cb120449899">(data)</a></span></span></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
#
#
# <!--
# NewPP limit report
# Parsed by mw1262
# Cached time: 20170228003833
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.060 seconds
# Real time usage: 0.084 seconds
# Preprocessor visited node count: 219/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 3742/2097152 bytes
# Template argument size: 183/2097152 bytes
# Highest expansion depth: 12/40
# Expensive parser function count: 2/500
# Lua time usage: 0.027/10.000 seconds
# Lua memory usage: 949 KB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%   68.380      1 -total
#  49.21%   33.650      1 Template:Lang-ru
#  47.12%   32.221      1 Template:Language_with_name_and_transliteration
#  44.21%   30.231      1 Template:Lang
#  42.81%   29.272      1 Template:Authority_control
#  40.86%   27.942      1 Template:Category_handler
#   4.72%    3.230      1 Template:Reflist
#   2.57%    1.755      2 Template:ISO_639_name
#   0.95%    0.652      2 Template:ISO_639_name_ru
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:7502081-0!*!0!!en!*!* and timestamp 20170228003833 and revision id 736718079
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Valentin_Yanin&amp;oldid=736718079">https://en.wikipedia.org/w/index.php?title=Valentin_Yanin&amp;oldid=736718079</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Living_people" title="Category:Living people">Living people</a></li><li><a href="/wiki/Category:1929_births" title="Category:1929 births">1929 births</a></li><li><a href="/wiki/Category:Russian_historians" title="Category:Russian historians">Russian historians</a></li><li><a href="/wiki/Category:Soviet_historians" title="Category:Soviet historians">Soviet historians</a></li><li><a href="/wiki/Category:20th-century_historians" title="Category:20th-century historians">20th-century historians</a></li><li><a href="/wiki/Category:Russian_archaeologists" title="Category:Russian archaeologists">Russian archaeologists</a></li><li><a href="/wiki/Category:Soviet_archaeologists" title="Category:Soviet archaeologists">Soviet archaeologists</a></li><li><a href="/wiki/Category:Moscow_State_University_alumni" title="Category:Moscow State University alumni">Moscow State University alumni</a></li><li><a href="/wiki/Category:Moscow_State_University_faculty" title="Category:Moscow State University faculty">Moscow State University faculty</a></li><li><a href="/wiki/Category:Historians_of_Russia" title="Category:Historians of Russia">Historians of Russia</a></li><li><a href="/wiki/Category:Full_Members_of_the_USSR_Academy_of_Sciences" title="Category:Full Members of the USSR Academy of Sciences">Full Members of the USSR Academy of Sciences</a></li><li><a href="/wiki/Category:Full_Members_of_the_Russian_Academy_of_Sciences" title="Category:Full Members of the Russian Academy of Sciences">Full Members of the Russian Academy of Sciences</a></li><li><a href="/wiki/Category:Demidov_Prize_laureates" title="Category:Demidov Prize laureates">Demidov Prize laureates</a></li><li><a href="/wiki/Category:Solzhenitsyn_Prize_winners" title="Category:Solzhenitsyn Prize winners">Solzhenitsyn Prize winners</a></li><li><a href="/wiki/Category:Lenin_Prize_winners" title="Category:Lenin Prize winners">Lenin Prize winners</a></li><li><a href="/wiki/Category:Recipients_of_the_USSR_State_Prize" title="Category:Recipients of the USSR State Prize">Recipients of the USSR State Prize</a></li><li><a href="/wiki/Category:Recipients_of_the_Lomonosov_Gold_Medal" title="Category:Recipients of the Lomonosov Gold Medal">Recipients of the Lomonosov Gold Medal</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_of_Lenin" title="Category:Recipients of the Order of Lenin">Recipients of the Order of Lenin</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_of_the_Red_Banner_of_Labour" title="Category:Recipients of the Order of the Red Banner of Labour">Recipients of the Order of the Red Banner of Labour</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_%22For_Merit_to_the_Fatherland%22,_4th_class" title="Category:Recipients of the Order &quot;For Merit to the Fatherland&quot;, 4th class">Recipients of the Order &quot;For Merit to the Fatherland&quot;, 4th class</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Articles_containing_Russian-language_text" title="Category:Articles containing Russian-language text">Articles containing Russian-language text</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_VIAF_identifiers" title="Category:Wikipedia articles with VIAF identifiers">Wikipedia articles with VIAF identifiers</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_LCCN_identifiers" title="Category:Wikipedia articles with LCCN identifiers">Wikipedia articles with LCCN identifiers</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_BNF_identifiers" title="Category:Wikipedia articles with BNF identifiers">Wikipedia articles with BNF identifiers</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Valentin+Yanin" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Valentin+Yanin" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Valentin_Yanin"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Valentin_Yanin"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Valentin_Yanin" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Valentin_Yanin&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Valentin_Yanin" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Valentin_Yanin" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Valentin_Yanin&amp;oldid=736718079" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Valentin_Yanin&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q1980377" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Valentin_Yanin&amp;id=736718079" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Valentin+Yanin">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Valentin+Yanin&amp;returnto=Valentin+Yanin&amp;oldid=736718079&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Valentin_Yanin&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-eo"><a href="https://eo.wikipedia.org/wiki/Valentin_Janin" title="Valentin Janin – Esperanto" lang="eo" hreflang="eo" class="interlanguage-link-target">Esperanto</a></li><li class="interlanguage-link interwiki-fr"><a href="https://fr.wikipedia.org/wiki/Valentin_Ianine" title="Valentin Ianine – French" lang="fr" hreflang="fr" class="interlanguage-link-target">Français</a></li><li class="interlanguage-link interwiki-ru"><a href="https://ru.wikipedia.org/wiki/%D0%AF%D0%BD%D0%B8%D0%BD,_%D0%92%D0%B0%D0%BB%D0%B5%D0%BD%D1%82%D0%B8%D0%BD_%D0%9B%D0%B0%D0%B2%D1%80%D0%B5%D0%BD%D1%82%D1%8C%D0%B5%D0%B2%D0%B8%D1%87" title="Янин, Валентин Лаврентьевич – Russian" lang="ru" hreflang="ru" class="interlanguage-link-target">Русский</a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q1980377#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 29 August 2016, at 11:26.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Valentin_Yanin&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.060","walltime":"0.084","ppvisitednodes":{"value":219,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":3742,"limit":2097152},"templateargumentsize":{"value":183,"limit":2097152},"expansiondepth":{"value":12,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%   68.380      1 -total"," 49.21%   33.650      1 Template:Lang-ru"," 47.12%   32.221      1 Template:Language_with_name_and_transliteration"," 44.21%   30.231      1 Template:Lang"," 42.81%   29.272      1 Template:Authority_control"," 40.86%   27.942      1 Template:Category_handler","  4.72%    3.230      1 Template:Reflist","  2.57%    1.755      2 Template:ISO_639_name","  0.95%    0.652      2 Template:ISO_639_name_ru"]},"scribunto":{"limitreport-timeusage":{"value":"0.027","limit":"10.000"},"limitreport-memusage":{"value":971837,"limit":52428800}},"cachereport":{"origin":"mw1262","timestamp":"20170228003833","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":173,"wgHostname":"mw1262"});});</script>
# 	</body>
# </html>

# %% [markdown]
# Read all of the files into list called content.
# Each value in the list should the the content of a file.
# Create a list called articles that contains the article names.
# These should be the filename without the wiki/ prefix, and the .html suffix.

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers=2)

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

end = time.time()
print(end - start)
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]
# Out:
# 0.31409525871276855

# %% [markdown]
# Extracts the content div from the page.

# %%
from bs4 import BeautifulSoup

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=2)
parsed = pool.map(parse_html, content)
parsed = list(parsed)
end = time.time()

print(end - start)
# Out:
# 51.942405700683594

# %%
parsed[0]
# Out:
# '<div class="mw-body" id="content" role="main">\n<a id="top"></a>\n<div id="siteNotice"><!-- CentralNotice --></div>\n<div class="mw-indicators">\n</div>\n<h1 class="firstHeading" id="firstHeading" lang="en">Furubira District, Hokkaido</h1>\n<div class="mw-body-content" id="bodyContent">\n<div id="siteSub">From Wikipedia, the free encyclopedia</div>\n<div id="contentSub"></div>\n<div class="mw-jump" id="jump-to-nav">\n\t\t\t\t\tJump to:\t\t\t\t\t<a href="#mw-head">navigation</a>, \t\t\t\t\t<a href="#p-search">search</a>\n</div>\n<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><table class="plainlinks metadata ambox ambox-content ambox-Unreferenced" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div>\n</td>\n<td class="mbox-text"><span class="mbox-text-span">This article <b>does not <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">cite</a> any <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">sources</a></b>. <span class="hide-when-compact">Please help <a class="external text" href="//en.wikipedia.org/w/index.php?title=Furubira_District,_Hokkaido&amp;action=edit">improve this article</a> by <a href="/wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1" title="Help:Introduction to referencing with Wiki Markup/1">adding citations to reliable sources</a>. Unsourced material may be challenged and <a href="/wiki/Wikipedia:Verifiability#Burden_of_evidence" title="Wikipedia:Verifiability">removed</a>.</span> <small><i>(December 2009)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>\n</tr>\n</table>\n<div class="thumb tright">\n<div class="thumbinner" style="width:202px;"><a class="image" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif"><img alt="" class="thumbimage" data-file-height="368" data-file-width="600" height="123" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/200px-Furubira_in_Shiribeshi_Subprefecture.gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/300px-Furubira_in_Shiribeshi_Subprefecture.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/400px-Furubira_in_Shiribeshi_Subprefecture.gif 2x" width="200"/></a>\n<div class="thumbcaption">\n<div class="magnify"><a class="internal" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif" title="Enlarge"></a></div>\nFurubira in Shiribeshi Subprefecture.</div>\n</div>\n</div>\n<p><b>Furubira</b> <span style="font-weight: normal">(<span class="t_nihongo_kanji" lang="ja" xml:lang="ja">古平郡</span><span class="t_nihongo_comma" style="display:none">,</span> <i>Furubira-gun</i><sup class="t_nihongo_help noprint"><a href="/wiki/Help:Installing_Japanese_character_sets" title="Help:Installing Japanese character sets"><span class="t_nihongo_icon" style="color: #00e; font: bold 80% sans-serif; text-decoration: none; padding: 0 .1em;">?</span></a></sup>)</span> is a <a href="/wiki/Districts_of_Japan" title="Districts of Japan">district</a> located in <a href="/wiki/Shiribeshi_Subprefecture" title="Shiribeshi Subprefecture">Shiribeshi Subprefecture</a>, <a href="/wiki/Hokkaido" title="Hokkaido">Hokkaido</a>, <a href="/wiki/Japan" title="Japan">Japan</a>.</p>\n<p>As of 2004, the district has an es ...

# %% [markdown]
# Display the tag counts

# %%
from bs4 import BeautifulSoup

def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)
tags = list(tags)

tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
end = time.time()

print(end - start)
tag_counts
# Out:
# 24.723746061325073
# {'a': 161065,
#  'abbr': 3665,
#  'annotation': 2,
#  'area': 39,
#  'audio': 2,
#  'b': 14455,
#  'bdi': 4,
#  'big': 75,
#  'blockquote': 58,
#  'br': 4986,
#  'caption': 200,
#  'center': 64,
#  'cite': 3563,
#  'code': 108,
#  'dd': 1376,
#  'del': 2,
#  'div': 28581,
#  'dl': 457,
#  'dt': 334,
#  'font': 40,
#  'h1': 999,
#  'h2': 4045,
#  'h3': 777,
#  'h4': 117,
#  'h5': 4,
#  'h6': 1,
#  'hr': 51,
#  'i': 18246,
#  'img': 6701,
#  'li': 85779,
#  'map': 2,
#  'math': 2,
#  'mo': 2,
#  'mrow': 2,
#  'mstyle': 2,
#  'noscript': 999,
#  'ol': 858,
#  'p': 7998,
#  'pre': 1,
#  'q': 76,
#  'rb': 16,
#  'rp': 32,
#  'rt': 16,
#  'ruby': 16,
#  's': 10,
#  'samp': 2,
#  'semantics': 2,
#  'small': 3272,
#  'source': 2,
#  'span': 67350,
#  'strong': 599,
#  'sub': 151,
#  'sup': 11157,
#  'table': 4010,
#  'td': 57673,
#  'th': 14472,
#  'tr': 27300,
#  'u': 51,
#  'ul': 10972,
#  'wbr': 85}

# %% [markdown]
# overall word counts across all of the documents

# %%
from bs4 import BeautifulSoup
from collections import Counter
import re

def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(10)

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
end = time.time()

print(end - start)
word_counts
# Out:
# 25.577786207199097
# {'santiago': 1,
#  'classification': 3,
#  'twenty20': 1,
#  'cordeiro': 1,
#  'resting': 1,
#  'saudi': 2,
#  'melbourne': 3,
#  'charts': 4,
#  'number': 9,
#  'clock': 1,
#  'fencing': 1,
#  'union': 16,
#  'queen': 7,
#  'løwert': 1,
#  'territory': 1,
#  'flute': 1,
#  'bloomer': 1,
#  'thornton': 1,
#  'speedway': 1,
#  'maccabees': 1,
#  'lanterns': 1,
#  'villers': 2,
#  'their': 25,
#  'permanent': 2,
#  'influenza': 1,
#  'tulrca': 1,
#  'theorem': 1,
#  'total': 4,
#  'mokala': 1,
#  'euston': 1,
#  'dresden': 2,
#  'phasianidae': 1,
#  'incidents': 1,
#  'horsey': 1,
#  'romanesque': 1,
#  'defeated': 1,
#  'cristian': 1,
#  'rezvanshahr': 1,
#  'stadium': 6,
#  'mahoning': 1,
#  'carlsberg': 1,
#  'cherry': 2,
#  'hollywood': 1,
#  'martin': 1,
#  'garfield': 2,
#  'peltigera': 1,
#  'mines': 1,
#  'wayback': 3,
#  'creative': 1,
#  'released': 19,
#  'pastorious': 1,
#  'coast': 5,
#  'grahamstown': 1,
#  'kyrgyzstan': 1,
#  'apparent': 1,
#  'musculoskeletal': 1,
#  'kelvin': 2,
#  'medical': 6,
#  'rouergue': 1,
#  'achaea': 1,
#  'blocks': 1,
#  'literary': 1,
#  'samples': 1,
#  'architecture': 2,
#  'referendums': 2,
#  'field': 9,
#  'frigate': 1,
#  'dowell': 1,
#  'république': 1,
#  'sykes': 1,
#  'attempts': 1,
#  'spilomelinae': 1,
#  'austin': 2,
#  'meade': 1,
#  'throw': 1,
#  'pradesh': 3,
#  'doumanaba': 1,
#  'barros': 1,
#  'syncretocarpus': 1,
#  'cortile': 1,
#  'brennan': 1,
#  'royal': 6,
#  'parna': 1,
#  'awali': 1,
#  'platform': 1,
#  'instrumental': 2,
#  'naxalbari': 1,
#  'battalions': 1,
#  'caffè': 1,
#  'fighting': 1,
#  'harbour': 1,
#  'schmadel': 1,
#  'beekeeper': 1,
#  'person': 3,
#  'america': 1,
#  'river': 14,
#  'shabbir': 1,
#  'hansa': 1,
#  'kjetil': 1,
#  'personality': 1,
#  'clear': 1,
#  'jephson': 1,
#  'colorado': 1,
#  'crossword': 1,
#  'student': 3,
#  'mannafar': 1,
#  'geomancer': 1,
#  'carolina': 8,
#  'daniel': 1,
#  'lantern': 1,
#  'album': 26,
#  'admiral': 1,
#  'faces': 1,
#  'psychiatric': 1,
#  'energy': 1,
#  'walsingham': 1,
#  'festivals': 1,
#  'gobeyr': 1,
#  'coastcomp': 1,
#  'jotedars': 1,
#  'coaches': 1,
#  'tatar': 1,
#  'réunion': 1,
#  'rasht': 1,
#  'uttar': 1,
#  'congress': 1,
#  'course': 2,
#  'coventry': 1,
#  'pseudoluteata': 1,
#  'shake': 1,
#  'operation': 2,
#  'congregation': 1,
#  'register': 15,
#  'exploratorium': 1,
#  'bericoides': 1,
#  'mammoth': 1,
#  'swing': 3,
#  'inscription': 1,
#  'esporte': 1,
#  'walker': 3,
#  'actor': 8,
#  '07806': 1,
#  'honey': 1,
#  'athletics': 5,
#  'light': 1,
#  'plana': 1,
#  'south': 26,
#  'panic': 1,
#  'roofing': 1,
#  'auckland': 1,
#  'frithjof': 1,
#  'videos': 1,
#  'tischofer': 1,
#  'petersen': 1,
#  'player': 4,
#  'surnamesitalian': 1,
#  'paraguay': 1,
#  'final': 4,
#  'journal': 6,
#  'syngenor': 1,
#  'okpatu': 1,
#  'forewings': 1,
#  'ramsayville': 1,
#  'ahmad': 1,
#  'colonel': 1,
#  'wysokie': 1,
#  'specific': 1,
#  'length': 3,
#  'sofie': 1,
#  'logic': 1,
#  'trust': 1,
#  'retail': 1,
#  'tulcea': 1,
#  'machuca': 1,
#  'remix': 1,
#  'kumar': 1,
#  'gloucester': 1,
#  'languages': 2,
#  'complex': 1,
#  'sheath': 1,
#  'carlos': 2,
#  'samoan': 1,
#  'tillis': 1,
#  'valgus': 1,
#  'camera': 1,
#  'calculators': 1,
#  'presidential': 2,
#  'saratoga': 1,
#  'funny': 1,
#  'roxbury': 1,
#  'accession': 1,
#  'beautiful': 1,
#  'tamil': 4,
#  'services': 4,
#  'author': 2,
#  'zhejiang': 1,
#  'newspaper': 1,
#  'vanek': 1,
#  'negative': 1,
#  'television': 16,
#  'asadabad': 1,
#  'wilcox': 1,
#  'brooks': 1,
#  'brecknock': 1,
#  'insulin': 1,
#  'coalition': 1,
#  'placid': 1,
#  'brunswick': 1,
#  'yasid': 1,
#  'cotton': 1,
#  'nickel': 1,
#  'citations': 8,
#  'electoral': 2,
#  'fairy': 1,
#  'speakers': 1,
#  'fraser': 2,
#  'flashbacks': 1,
#  'leicester': 1,
#  'plant': 7,
#  'malaysia': 2,
#  'miniseries': 2,
#  'manuscript': 1,
#  'pakistan': 3,
#  'hamconius': 1,
#  'hungarian': 1,
#  'vitruvius': 1,
#  'performed': 2,
#  'given': 2,
#  'scrobipalpa': 1,
#  'karluk': 1,
#  'appearances': 4,
#  'llwyn': 1,
#  'compound': 1,
#  'laniidae': 1,
#  'reims': 2,
#  'mughals': 1,
#  'bazemore': 1,
#  'mcdonald': 2,
#  'companies': 2,
#  'journalist': 1,
#  '1880s': 1,
#  'bardhaman': 1,
#  'pudica': 1,
#  'preserve': 1,
#  'sickmen': 1,
#  'songwriter': 1,
#  'warbler': 1,
#  'province': 14,
#  'special': 2,
#  'coordinates': 22,
#  'houston': 1,
#  'dasmariñas': 1,
#  'paintings': 1,
#  'coenaculum': 1,
#  'dublin': 2,
#  'origin': 1,
#  'ohlsson': 1,
#  'muirí': 1,
#  'fletcher': 1,
#  'planetary': 1,
#  'terrorism': 1,
#  'surname': 4,
#  'similis': 1,
#  'skiing': 2,
#  'wildlife': 1,
#  'magnetic': 1,
#  'heroines': 1,
#  'nematode': 1,
#  'cryptographic': 1,
#  'women': 20,
#  'solydxk': 1,
#  'keeping': 1,
#  'giang': 1,
#  'singular': 1,
#  'amborellaceae': 1,
#  '77694': 1,
#  'anime': 1,
#  'larry': 1,
#  'flatbill': 1,
#  'gardens': 1,
#  'pierre': 1,
#  'sangro': 1,
#  'fresh': 1,
#  'casimcea': 1,
#  'hutson': 1,
#  'flemish': 1,
#  'genotypes': 1,
#  'huang': 1,
#  'glutamyltransferase': 1,
#  'beekeeping': 1,
#  'growth': 2,
#  'columns': 2,
#  'original': 9,
#  'spence': 1,
#  'chromosome': 1,
#  'bombing': 1,
#  'diocese': 2,
#  'angustata': 1,
#  'internet': 1,
#  'products': 3,
#  'vineyards': 1,
#  'defensor': 1,
#  'stade': 1,
#  'docking': 1,
#  'reuten': 1,
#  'tides': 1,
#  'shire': 1,
#  'valdivia': 1,
#  'kyokutou': 1,
#  'guantanamo': 2,
#  'surgical': 1,
#  'petrovsky': 1,
#  'laker': 1,
#  'wrasse': 1,
#  'erigeron': 1,
#  'philaeus': 1,
#  'lines': 2,
#  'eyespots': 1,
#  'paintersitalian': 1,
#  'eugen': 2,
#  'italy': 5,
#  'gamede': 1,
#  'skoda': 1,
#  'uncertainty': 1,
#  'price': 2,
#  'pirate': 1,
#  'boneval': 1,
#  'vertical': 1,
#  'chart': 11,
#  'brownfield': 1,
#  'layer': 1,
#  'passed': 1,
#  'arrondissements': 1,
#  'hepialidae': 1,
#  'william': 15,
#  'interactive': 1,
#  'braquenié': 1,
#  'spirit': 1,
#  'diakonoff': 2,
#  'being': 2,
#  'josiah': 1,
#  '1960s': 1,
#  'flying': 1,
#  'moral': 1,
#  'quidem': 1,
#  'eisenhower': 1,
#  'bullying': 1,
#  'sacks': 1,
#  'kurata': 1,
#  'razões': 1,
#  'standard': 1,
#  'diagnosis': 1,
#  'workshops': 1,
#  'cartel': 1,
#  '59861': 1,
#  'kensington': 1,
#  'bundela': 1,
#  'ellington': 1,
#  'sculptor': 1,
#  'maria': 2,
#  'hoosiers': 1,
#  'landhi': 1,
#  'mérida': 1,
#  'promises': 1,
#  'candidate': 3,
#  'caliber': 1,
#  'prepared': 1,
#  'chapel': 2,
#  'gennady': 1,
#  'wyszonki': 1,
#  'rockford': 1,
#  'magazine': 6,
#  'chesney': 1,
#  'supermoon': 1,
#  'indicated': 1,
#  'sierra': 4,
#  'gewächshaus': 1,
#  'adelaide': 1,
#  '83250': 1,
#  'caesar': 1,
#  'morocco': 1,
#  'srrsh': 1,
#  'bhubaneswar': 1,
#  'bijar': 1,
#  'partnered': 1,
#  'hebden': 1,
#  'balasagun': 1,
#  'luleå': 1,
#  'children': 9,
#  'rockin': 1,
#  'yonne': 1,
#  'storm': 2,
#  'genus': 15,
#  'breeds': 1,
#  'super': 2,
#  'translation': 4,
#  'fejervarya': 1,
#  'studio': 4,
#  'committee': 1,
#  'feiglin': 1,
#  'spelman': 1,
#  'ordovician': 1,
#  'bandholtz': 1,
#  'arthur': 1,
#  'uruguay': 1,
#  'scotia': 1,
#  'cosmopterix': 1,
#  'hagen': 1,
#  'lieutenant': 1,
#  'those': 2,
#  'burdine': 1,
#  'nalbant': 1,
#  'maximus': 3,
#  'never': 1,
#  'highway': 2,
#  'matagorda': 1,
#  'orange': 2,
#  'polish': 4,
#  'fureai': 1,
#  'solomona': 1,
#  'states': 38,
#  'center': 8,
#  'belarusian': 2,
#  'axial': 1,
#  'elections': 9,
#  'kettu': 1,
#  'court': 6,
#  'chemical': 3,
#  'hawaii': 1,
#  'vosta': 1,
#  'directed': 4,
#  'margins': 1,
#  'yarkand': 1,
#  'fritz': 1,
#  'tachinidae': 1,
#  'soyuz': 1,
#  'jonas': 1,
#  'madeira': 1,
#  'problem': 1,
#  'institut': 1,
#  'economic': 2,
#  'sayed': 1,
#  'latinos': 1,
#  'mazowieckie': 1,
#  'pluto': 1,
#  'isaac': 1,
#  'songs': 7,
#  'commons': 1,
#  'party': 17,
#  'derived': 1,
#  'bradley': 1,
#  'formula': 3,
#  'manufacturing': 1,
#  'finnish': 2,
#  'laxmikant': 1,
#  'dissociation': 1,
#  'elgin': 1,
#  'biztalk': 1,
#  'played': 8,
#  'løgtingið': 1,
#  'speaking': 2,
#  'thessalonica': 1,
#  'escarré': 1,
#  'thikana': 1,
#  '4127286': 1,
#  'composers': 1,
#  'sénia': 1,
#  'capacity': 1,
#  'svalbard': 1,
#  'arkansas': 4,
#  'simone': 1,
#  'ahvaz': 1,
#  'kevoo': 1,
#  'kingston': 1,
#  'stanchovtsi': 2,
#  'industry': 1,
#  'reign': 1,
#  'urban': 3,
#  'making': 1,
#  'kamenogorsk': 1,
#  'zehut': 1,
#  'platinum': 2,
#  'freeman': 1,
#  'interacting': 1,
#  'mucci': 1,
#  'vincenç': 1,
#  '701335': 1,
#  'whewell': 1,
#  'gondry': 1,
#  'yeats': 1,
#  'volleyball': 2,
#  'springs': 1,
#  'shikoku': 2,
#  'conferences': 1,
#  'youtube': 2,
#  'tunnel': 1,
#  'change': 1,
#  'villeneuve': 1,
#  'evene': 1,
#  'mirisah': 1,
#  'cárdenas': 1,
#  'sinfonia': 1,
#  'carol': 1,
#  'aragon': 1,
#  'footballer': 2,
#  'daybreak': 1,
#  'zlotowitz': 1,
#  'bicolor': 1,
#  'cusack': 1,
#  'kōchi': 2,
#  'result': 1,
#  'bengal': 2,
#  'liverpool': 1,
#  'municipality': 9,
#  'sites': 1,
#  'caramagna': 1,
#  'hadeth': 1,
#  'maram': 1,
#  'vinci': 1,
#  'nationale': 3,
#  'famous': 1,
#  'stories': 1,
#  'samoa': 2,
#  'crater': 2,
#  'sciences': 1,
#  'oklahoma': 3,
#  'catostomus': 1,
#  'grünewald': 1,
#  'agnolin': 1,
#  'described': 5,
#  'gorfion': 1,
#  'engineering': 7,
#  'claire': 1,
#  'listed': 1,
#  'ayish': 1,
#  'barneveld': 1,
#  'información': 1,
#  'kummerow': 1,
#  'kellie': 1,
#  'pieces': 1,
#  'britain': 3,
#  'khanapur': 1,
#  'qualifier': 1,
#  'mafia': 2,
#  'simulation': 1,
#  'leuke': 1,
#  'shorthand': 1,
#  'comedy': 4,
#  'guide': 3,
#  'article': 73,
#  'flores': 1,
#  'productions': 1,
#  'perth': 1,
#  'messianic': 1,
#  'parallel': 2,
#  'graah': 1,
#  'golabkhvaran': 1,
#  '711848449': 1,
#  'darts': 1,
#  'farbridge': 1,
#  'bijnor': 1,
#  'sediment': 1,
#  'montreal': 2,
#  'reveals': 1,
#  'names': 8,
#  'colpo': 1,
#  'kenyan': 1,
#  'airports': 5,
#  'blues': 5,
#  'braille': 1,
#  'resigned': 1,
#  'london': 8,
#  'cocker': 1,
#  'boeke': 1,
#  '55056': 1,
#  'karnataka': 3,
#  'painter': 3,
#  'bastards': 1,
#  'basal': 1,
#  'ismacryp': 1,
#  'richard': 4,
#  'petrolero': 1,
#  'avenira': 1,
#  'zimbabwe': 1,
#  'estate': 1,
#  'brigade': 1,
#  'bijuba': 1,
#  'ushiba': 1,
#  'hardy': 1,
#  'finger': 1,
#  'idaho': 1,
#  'kearfott': 1,
#  'istanbul': 1,
#  'dodger': 1,
#  'touch': 1,
#  'cruze': 1,
#  'little': 1,
#  'forbidden': 1,
#  'frosinone': 1,
#  'hjertén': 1,
#  'maple': 1,
#  'greek': 8,
#  'ingrid': 1,
#  'churches': 2,
#  'germany': 16,
#  'saravan': 1,
#  '09278': 1,
#  '37806': 1,
#  'trail': 1,
#  'groupe': 1,
#  'incorporating': 2,
#  'rally': 3,
#  'hasbro': 1,
#  'finish': 2,
#  '32194': 1,
#  'church': 18,
#  '598699': 1,
#  'league': 30,
#  'aleksandra': 1,
#  'tumbes': 1,
#  'mental': 2,
#  'plasnewydd': 1,
#  'pitcher': 2,
#  'flight': 2,
#  'blessed': 1,
#  'copenhagen': 1,
#  'erotic': 1,
#  'kotar': 1,
#  'strut': 1,
#  'haiti': 1,
#  'ranga': 1,
#  'kamakhyanagar': 1,
#  'solanales': 1,
#  'octomeria': 1,
#  'disease': 1,
#  'these': 6,
#  'tulem': 1,
#  'auditor': 1,
#  'orthaea': 1,
#  'focusing': 1,
#  'robert': 10,
#  'llerena': 1,
#  'eight': 1,
#  '38750': 1,
#  'texas': 11,
#  'dolls': 1,
#  'newman': 1,
#  'talent': 1,
#  'curling': 2,
#  '3500306': 1,
#  'flowing': 1,
#  'cosmonaut': 1,
#  'muslims': 2,
#  'shoreyjeh': 1,
#  'abstraction': 1,
#  'fortuin': 1,
#  'disciplines': 1,
#  'speer': 1,
#  'doubles': 2,
#  'cricketer': 2,
#  'pathans': 1,
#  'lopez': 1,
#  'shirley': 1,
#  'guarro': 1,
#  'tbilisi': 1,
#  'rissoidae': 1,
#  'artscroll': 1,
#  'brazil': 2,
#  'index': 5,
#  'dressage': 1,
#  'calderón': 1,
#  'tweevils': 1,
#  'singles': 8,
#  'gijón': 1,
#  'calderini': 1,
#  'pérez': 1,
#  'twist': 2,
#  'portugal': 3,
#  'fluminense': 1,
#  'brother': 2,
#  'diplacus': 1,
#  'structure': 5,
#  'pueblo': 1,
#  'rouen': 1,
#  'mundo': 1,
#  'national': 37,
#  'julian': 1,
#  'defence': 1,
#  'forster': 1,
#  'reference': 1,
#  'precorrin': 1,
#  'profile': 2,
#  'theory': 2,
#  '10000': 1,
#  'marin': 1,
#  'pagenstecher': 1,
#  'plzeň': 2,
#  'millot': 1,
#  'remove': 5,
#  'wolfpack': 1,
#  'untersuchungen': 1,
#  'railroad': 1,
#  'imereti': 1,
#  'pinker': 1,
#  'measure': 1,
#  'sultanate': 1,
#  'minurcat': 1,
#  'florabase': 1,
#  'aylon': 1,
#  'bathurst': 1,
#  'pochyta': 1,
#  'prokop': 1,
#  'chico': 1,
#  'baptist': 1,
#  'armato': 1,
#  'donje': 1,
#  'qualifying': 1,
#  'march': 24,
#  'chemistry': 2,
#  'mayor': 5,
#  'giesbert': 1,
#  'planets': 1,
#  'antarctica': 1,
#  'unclear': 1,
#  'oliver': 2,
#  'pancamo': 1,
#  'zgornji': 1,
#  'cancrivora': 1,
#  'military': 7,
#  'dornblaser': 1,
#  '70000': 1,
#  'möschler': 1,
#  'lollobrigida': 1,
#  'https': 1,
#  'shahr': 2,
#  'edmonton': 2,
#  'sibling': 1,
#  'mamatey': 1,
#  'seine': 1,
#  'kabud': 1,
#  'maron': 1,
#  'nellie': 1,
#  'processes': 1,
#  'eastward': 1,
#  'mumbai': 2,
#  'superfamily': 1,
#  'facilities': 1,
#  'wrocław': 1,
#  'nepenthes': 1,
#  'nathan': 1,
#  'dasht': 1,
#  'stations': 13,
#  'puerto': 2,
#  'dorgali': 1,
#  'flowers': 2,
#  'bogan': 1,
#  'devil': 2,
#  'bangkok': 1,
#  'prize': 2,
#  'biographical': 2,
#  'stanyan': 1,
#  'klein': 1,
#  'marine': 8,
#  'acquisition': 1,
#  'taipei': 1,
#  'jezebel': 1,
#  'detention': 2,
#  'impact': 1,
#  'technical': 2,
#  'marcello': 1,
#  'trojans': 1,
#  'andhra': 1,
#  'martinus': 1,
#  'nueva': 1,
#  'fireman': 1,
#  'andreeva': 1,
#  'suigun': 1,
#  'beneficiary': 1,
#  'christian': 1,
#  'heinz': 1,
#  'conservation': 2,
#  'cybernetics': 1,
#  'greece': 1,
#  'hemet': 1,
#  'cronache': 1,
#  'ansari': 1,
#  'acyltransferase': 1,
#  'toronto': 4,
#  'clade': 5,
#  'warkworth': 1,
#  'impeccable': 1,
#  'kenny': 4,
#  'peking': 1,
#  'detroit': 1,
#  'cercle': 1,
#  'tournaments': 1,
#  'guaratuba': 1,
#  'nobuhiko': 1,
#  'beauty': 1,
#  'intermedia': 1,
#  'comics': 4,
#  'thing': 1,
#  'border': 2,
#  'eolica': 1,
#  'governor': 3,
#  'coalville': 1,
#  'inhibitors': 1,
#  'truss': 1,
#  'minnow': 1,
#  'lasse': 1,
#  'bexley': 1,
#  'tetrapods': 1,
#  'marathi': 1,
#  'vivian': 1,
#  'champions': 1,
#  'omiodes': 1,
#  'svinjare': 1,
#  'purdy': 1,
#  'anderson': 1,
#  'goran': 2,
#  'funding': 1,
#  'blutsch': 1,
#  'miguel': 1,
#  'experimental': 1,
#  '01333': 1,
#  'salal': 1,
#  'erceg': 1,
#  'nursery': 1,
#  'ankara': 1,
#  'kailas': 1,
#  'mythology': 1,
#  'david': 8,
#  'oxford': 4,
#  'evans': 1,
#  'brotherhood': 1,
#  'moths': 2,
#  'straight': 1,
#  'ainounah': 1,
#  'veturi': 1,
#  'eating': 1,
#  'alliance': 1,
#  'chełmno': 1,
#  'padifolium': 1,
#  '9780741451897': 1,
#  'chest': 1,
#  'mouse': 3,
#  'gorni': 2,
#  'cannes': 1,
#  'ladanyi': 1,
#  'germán': 1,
#  'toward': 2,
#  'airlines': 2,
#  'hideki': 1,
#  '29833': 1,
#  'tlélat': 1,
#  '4415306': 1,
#  'european': 2,
#  'kristi': 1,
#  'eighty': 1,
#  'smith': 6,
#  'maneswar': 1,
#  'gavião': 1,
#  'monterey': 1,
#  'plains': 2,
#  'metal': 1,
#  'falman': 1,
#  'limited': 3,
#  'eclipse': 1,
#  'million': 2,
#  'equality': 1,
#  'gordon': 3,
#  'mills': 1,
#  'hokkaido': 1,
#  'swindon': 1,
#  'aarhus': 1,
#  'ghost': 1,
#  'dining': 1,
#  'haute': 1,
#  'gazuiyeh': 1,
#  '086333': 1,
#  'early': 1,
#  'boston': 2,
#  'benin': 2,
#  'chicago': 5,
#  'howard': 2,
#  'pictographs': 1,
#  'polytaenia': 1,
#  'censor': 1,
#  'jeremy': 1,
#  'sebastião': 1,
#  'later': 3,
#  'technique': 1,
#  'wrote': 2,
#  'debian': 1,
#  'needing': 1,
#  'pirama': 1,
#  'esteem': 1,
#  'guerreiroi': 1,
#  'witzenhausen': 1,
#  'posthumous': 1,
#  'poiana': 1,
#  'wayne': 1,
#  'governorate': 2,
#  'dayton': 1,
#  'serena': 1,
#  'stores': 1,
#  'bands': 1,
#  'shioda': 1,
#  'eliteprospects': 1,
#  'savory': 1,
#  'ausserberg': 1,
#  'advertising': 1,
#  'demography': 1,
#  'fifth': 1,
#  'entire': 1,
#  'paraná': 1,
#  'agonist': 1,
#  '48056': 1,
#  'respiratory': 1,
#  'врила': 1,
#  'marshall': 1,
#  'programme': 3,
#  'choline': 1,
#  'selling': 1,
#  'understands': 1,
#  'presence': 1,
#  'methods': 1,
#  'olethreutinae': 1,
#  'enfants': 1,
#  'citation': 1,
#  'gender': 1,
#  'melanolagus': 1,
#  'amokwe': 1,
#  'romagna': 1,
#  'chestnuts': 1,
#  'odder': 1,
#  '54361': 1,
#  'kadamaha': 1,
#  'tomohiko': 1,
#  'yaboom': 1,
#  'theme': 1,
#  'louis': 3,
#  'suffragan': 1,
#  'quetzaltenango': 1,
#  'public': 7,
#  'deseret': 1,
#  'khikhani': 1,
#  'binding': 2,
#  'perigee': 1,
#  'american': 32,
#  'chandor': 1,
#  'performance': 3,
#  '39833': 1,
#  'linux': 2,
#  'natasha': 1,
#  'tommy': 1,
#  'miltochrista': 1,
#  'sasha': 1,
#  'ottoman': 1,
#  'tarsila': 1,
#  'judah': 1,
#  'kendalia': 1,
#  'tephritidae': 1,
#  'tirana': 1,
#  'herself': 1,
#  'banque': 1,
#  'singer': 4,
#  'области': 1,
#  'births1921': 1,
#  'schauspielhaus': 1,
#  'egyptian': 1,
#  'goreau': 1,
#  'tryavna': 2,
#  'featured': 1,
#  'vetriswaran': 1,
#  'widenhouse': 1,
#  'inspector': 1,
#  'reaction': 1,
#  'sabadell': 1,
#  'overstreet': 1,
#  'mosques': 1,
#  'artifacts': 1,
#  'cryptography': 1,
#  'allee': 1,
#  'redding': 1,
#  'shaikh': 1,
#  'washington': 4,
#  'grande': 1,
#  'moses': 1,
#  'kinda': 1,
#  'explorer': 1,
#  'antae': 1,
#  'storyboard': 1,
#  '59194': 1,
#  'clinic': 1,
#  'maegashira': 1,
#  'brașov': 1,
#  'róðrarfelag': 1,
#  'puisaye': 1,
#  'stock': 2,
#  ...}
